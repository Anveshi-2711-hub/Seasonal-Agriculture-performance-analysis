# %% [markdown]
# ## SEASONAL AGRICULTURE PERFORMANCE ANALYSIS
# The dataset represents agricultural activities carried out across different seasons, geographical areas and farming conditions. It contains information related to farming practices, environmental conditions, crop production, resource usage and economic
# performance.

# %% [markdown]
# # **Problem Statement:-**
# The problem is to analyze the given agricultural dataset andinvestigate seasonal differences in agricultural performance by identifying meaningful patterns, trends, relationships and
# variations within the available data.

# %% [markdown]
# # **Objective:-**
# The primary objective of this project is to analyze agriculturaldata from different seasons
# and identify meaningful patterns, trends, relationships and differences in agricultural
# performance.

# %% [markdown]
# # **Import all libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Load the dataset**

# %%
df = pd.read_csv("/content/seasonal agricultre performance.csv")

# %% [markdown]
# First 5 rows

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %% [markdown]
# First 5 columns

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %% [markdown]
# # **Understand the dataset**

# %% [markdown]
# Shape

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 4000
# Columns: 28

# %% [markdown]
# Column names

# %%
print(df.columns)
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %% [markdown]
# Data Types

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %% [markdown]
# Complete information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %% [markdown]
# For categorical columns

# %%
df.describe(include="object")
# Out:
#         Farm_ID           State  District  Crop  Season Irrigation_Method
# count      4000            4000      4000  4000    4000              4000
# unique     4000               8        10     8       3                 4
# top     SF13984  Andhra Pradesh  Ludhiana  Rice  Kharif             Flood
# freq          1             529       427   690    1779              1310

# %% [markdown]
# # **Check Missing Values**

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %% [markdown]
# Percentage

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# Farm_ID                          0.0
# State                            0.0
# District                         0.0
# Crop                             0.0
# Season                           0.0
# Farm_Area_Hectares               0.0
# Rainfall_mm                      1.2
# Avg_Temperature_C                0.0
# Humidity_pct                     0.0
# Sunlight_Hours_Day               0.0
# Soil_pH                          0.0
# Soil_Moisture_pct                1.0
# Nitrogen_kg_ha                   0.0
# Phosphorus_kg_ha                 0.0
# Potassium_kg_ha                  0.0
# Irrigation_Method                0.0
# Fertilizer_kg_ha                 0.0
# Pesticide_Litre_ha               0.0
# Seed_Quality_Score               0.0
# Yield_Tonnes_Ha                  0.8
# Production_Tonnes                0.0
# Market_Price_INR_Tonne           0.0
# Total_Cost_INR                   0.0
# Revenue_INR                      0.0
# Profit_INR                       0.0
# ...

# %% [markdown]
# Visualise

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values")
plt.show()

# %% [markdown]
# # **Remove duplicate records**

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# # **Identify categorical and numerical columns**

# %%
categorical_columns = df.select_dtypes(include=["object"]).columns
numeric_columns = df.select_dtypes(include=np.number).columns
print("Categorical Columns:")
print(categorical_columns)
print("\nNumerical Columns:")
print(numeric_columns)
# Out:
# Categorical Columns:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method'], dtype='object')
#
# Numerical Columns:
# Index(['Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C',
#        'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct',
#        'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %% [markdown]
# # **Dataset Analysis**

# %% [markdown]
# States

# %%
df["State"].nunique()
# Out:
# 8

# %%
df["State"].value_counts()
# Out:
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64

# %% [markdown]
# Districts

# %%
df["District"].nunique()
# Out:
# 10

# %%
df["District"].value_counts()
# Out:
# District
# Ludhiana    427
# Warangal    422
# Nalgonda    415
# Erode       403
# Rajkot      401
# Krishna     393
# Indore      392
# Guntur      390
# Raichur     386
# Nashik      371
# Name: count, dtype: int64

# %% [markdown]
# Crops

# %%
df["Crop"].nunique()
# Out:
# 8

# %%
df["Crop"].value_counts()
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %% [markdown]
# Seasons

# %%
df["Season"].nunique()
# Out:
# 3

# %%
df["Season"].value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %% [markdown]
# Irrigation Methods

# %%
df["Irrigation_Method"].value_counts()
# Out:
# Irrigation_Method
# Flood        1310
# Rainfed      1041
# Drip          915
# Sprinkler     734
# Name: count, dtype: int64

# %% [markdown]
# # **Season Distribution**

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="Season")
plt.title("Distribution of Agricultural Records Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Farms")
plt.show()

# %% [markdown]
# # **Seasonal Yield Analysis**

# %%
season_yield = df.groupby("Season")["Yield_Tonnes_Ha"].mean()
print(season_yield)
# Out:
# Season
# Kharif    5.643973
# Rabi      5.080498
# Zaid      4.665942
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha"
)
plt.title("Average Crop Yield Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.show()

# %%
season_yield_stats = df.groupby("Season")["Yield_Tonnes_Ha"].agg(
    ["mean", "median", "std", "min", "max"]
)
season_yield_stats
# Out:
#             mean  median        std  min     max
# Season
# Kharif  5.643973    1.95  14.419077  0.3  101.44
# Rabi    5.080498    1.66  12.825348  0.3   93.13
# Zaid    4.665942    1.45  11.317728  0.3   64.76

# %% [markdown]
# # **Production Across Seasons**

# %%
season_production = df.groupby("Season")["Production_Tonnes"].mean()
print(season_production)
# Out:
# Season
# Kharif    46.311192
# Rabi      41.486712
# Zaid      38.886111
# Name: Production_Tonnes, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Production_Tonnes"
)
plt.title("Average Agricultural Production Across Seasons")
plt.xlabel("Season")
plt.ylabel("Production (Tonnes)")
plt.show()

# %% [markdown]
# # **Economic Performance Across Seasons**

# %%
economic_summary = df.groupby("Season").agg({
    "Market_Price_INR_Tonne": "mean",
    "Total_Cost_INR": "mean",
    "Revenue_INR": "mean",
    "Profit_INR": "mean"
})
economic_summary
# Out:
#         Market_Price_INR_Tonne  Total_Cost_INR    Revenue_INR     Profit_INR
# Season
# Kharif            44850.906127   531804.408094  710719.055649  178914.647555
# Rabi              44747.974800   513836.578365  601526.048556   87689.470191
# Zaid              44212.033670   543976.728956  519171.904040  -24804.824916

# %% [markdown]
# Profit graph

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Profit_INR"
)
plt.title("Average Profit Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")
plt.show()

# %% [markdown]
# Revenue graph

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Revenue_INR"
)
plt.title("Average Revenue Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Revenue (INR)")
plt.show()

# %% [markdown]
# # **Cost vs Revenue vs Profit**

# %%
financial_summary = df.groupby("Season").agg(
    Average_Cost=("Total_Cost_INR", "mean"),
    Average_Revenue=("Revenue_INR", "mean"),
    Average_Profit=("Profit_INR", "mean")
)
financial_summary
# Out:
#          Average_Cost  Average_Revenue  Average_Profit
# Season
# Kharif  531804.408094    710719.055649   178914.647555
# Rabi    513836.578365    601526.048556    87689.470191
# Zaid    543976.728956    519171.904040   -24804.824916

# %%
financial_summary.plot(
    kind="bar",
    figsize=(10, 6)
)
plt.title("Cost, Revenue and Profit Across Seasons")
plt.xlabel("Season")
plt.ylabel("Amount (INR)")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # **Resource Usage Analysis**

# %%
resource_summary = df.groupby("Season").agg({
    "Fertilizer_kg_ha": "mean",
    "Pesticide_Litre_ha": "mean",
    "Water_Used_m3": "mean"
})
resource_summary
# Out:
#         Fertilizer_kg_ha  Pesticide_Litre_ha  Water_Used_m3
# Season
# Kharif        187.077965            5.079747    6102.201237
# Rabi          185.407068            5.024690    5846.987093
# Zaid          184.638047            5.171212    6419.893939

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(
    resource_summary,
    annot=True,
    fmt=".2f"
)
plt.title("Average Resource Usage Across Seasons")
plt.show()

# %% [markdown]
# # **Water Usage Analysis**

# %%
water_summary = df.groupby("Season").agg({
    "Water_Used_m3": "mean",
    "Water_Efficiency_t_per_1000m3": "mean"
})
water_summary
# Out:
#         Water_Used_m3  Water_Efficiency_t_per_1000m3
# Season
# Kharif    6102.201237                       5.891834
# Rabi      5846.987093                       5.186122
# Zaid      6419.893939                       4.413239

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Water_Used_m3"
)
plt.title("Average Water Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Water Used (m³)")
plt.show()

# %% [markdown]
# Water Efficiency

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Water_Efficiency_t_per_1000m3"
)
plt.title("Water Efficiency Across Seasons")
plt.xlabel("Season")
plt.ylabel("Tonnes per 1000 m³")
plt.show()

# %% [markdown]
# # **Environmental Conditions**

# %%
environment_summary = df.groupby("Season").agg({
    "Rainfall_mm": "mean",
    "Avg_Temperature_C": "mean",
    "Humidity_pct": "mean",
    "Sunlight_Hours_Day": "mean"
})
environment_summary
# Out:
#         Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day
# Season
# Kharif   852.084205          28.454019     71.812591            6.793367
# Rabi     436.000124          23.489183     57.893178            7.589797
# Zaid     299.421784          31.042088     52.012121            8.178788

# %%
environment_summary.plot(
    kind="bar",
    figsize=(12, 6)
)
plt.title("Environmental Conditions Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Value")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # **Rainfall vs Yield**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Rainfall vs Crop Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# **Correlation**

# %%
rainfall_yield_corr = df[
    ["Rainfall_mm", "Yield_Tonnes_Ha"]
].corr()
rainfall_yield_corr
# Out:
#                  Rainfall_mm  Yield_Tonnes_Ha
# Rainfall_mm         1.000000         0.030853
# Yield_Tonnes_Ha     0.030853         1.000000

# %%
df["Rainfall_mm"].corr(df["Yield_Tonnes_Ha"])
# Out:
# np.float64(0.03085301698272099)

# %% [markdown]
# # **Temperature vs Yield**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Avg_Temperature_C",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Temperature vs Crop Yield")
plt.xlabel("Average Temperature (°C)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# **Correlation**

# %%
df["Avg_Temperature_C"].corr(
    df["Yield_Tonnes_Ha"]
)
# Out:
# np.float64(0.009349466617301579)

# %% [markdown]
# # **Humidity vs Yield**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Humidity_pct",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Humidity vs Crop Yield")
plt.xlabel("Humidity (%)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# # **Soil Conditions vs Yield**

# %% [markdown]
# Soil pH

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Soil_pH",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Soil pH vs Crop Yield")
plt.xlabel("Soil pH")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# Soil Moisture

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Soil_Moisture_pct",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Soil Moisture vs Crop Yield")
plt.xlabel("Soil Moisture (%)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# # **Fertilizer vs Yield**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Fertilizer_kg_ha",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Fertilizer Usage vs Crop Yield")
plt.xlabel("Fertilizer (kg/ha)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# Correlation

# %%
df["Fertilizer_kg_ha"].corr(
    df["Yield_Tonnes_Ha"]
)
# Out:
# np.float64(0.0005618892795134815)

# %% [markdown]
# # **Seed Quality vs Yield**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Seed_Quality_Score",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Seed Quality vs Crop Yield")
plt.xlabel("Seed Quality Score")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %% [markdown]
# Correlation

# %%
df["Seed_Quality_Score"].corr(
    df["Yield_Tonnes_Ha"]
)
# Out:
# np.float64(-0.006736713918859173)

# %% [markdown]
# # **Irrigation Method Analysis**

# %%
pd.crosstab(
    df["Season"],
    df["Irrigation_Method"]
)
# Out:
# Irrigation_Method  Drip  Flood  Rainfed  Sprinkler
# Season
# Kharif              405    590      463        321
# Rabi                370    526      438        293
# Zaid                140    194      140        120

# %%
irrigation_season = pd.crosstab(
    df["Season"],
    df["Irrigation_Method"],
    normalize="index"
) * 100
irrigation_season
# Out:
# Irrigation_Method       Drip      Flood    Rainfed  Sprinkler
# Season
# Kharif             22.765599  33.164699  26.025857  18.043845
# Rabi               22.741242  32.329441  26.920713  18.008605
# Zaid               23.569024  32.659933  23.569024  20.202020

# %%
irrigation_season.plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6)
)
plt.title("Irrigation Methods Across Seasons")
plt.xlabel("Season")
plt.ylabel("Percentage")
plt.xticks(rotation=0)
plt.legend(title="Irrigation Method")
plt.show()

# %% [markdown]
# # **Irrigation Method vs Yield**

# %%
irrigation_yield = df.groupby(
    "Irrigation_Method"
)["Yield_Tonnes_Ha"].mean().sort_values(
    ascending=False
)
irrigation_yield
# Out:
# Irrigation_Method
# Drip         6.620662
# Sprinkler    5.188819
# Flood        4.897724
# Rainfed      4.613182
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(
    x=irrigation_yield.index,
    y=irrigation_yield.values
)
plt.title("Average Yield by Irrigation Method")
plt.xlabel("Irrigation Method")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Region-wise Seasonal Analysis**

# %%
state_season = pd.crosstab(
    df["State"],
    df["Season"]
)
state_season
# Out:
# Season          Kharif  Rabi  Zaid
# State
# Andhra Pradesh     240   204    85
# Gujarat            221   200    67
# Karnataka          209   206    74
# Madhya Pradesh     226   208    63
# Maharashtra        222   218    72
# Punjab             221   186    77
# Tamil Nadu         206   208    71
# Telangana          234   197    85

# %%
state_yield = df.groupby(
    "State"
)["Yield_Tonnes_Ha"].mean().sort_values(
    ascending=False
)
state_yield
# Out:
# State
# Punjab            6.121116
# Karnataka         5.734493
# Gujarat           5.699586
# Telangana         5.076810
# Maharashtra       5.030333
# Madhya Pradesh    5.029654
# Tamil Nadu        4.901247
# Andhra Pradesh    4.650781
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=state_yield.index,
    y=state_yield.values
)
plt.title("Average Yield by State")
plt.xlabel("State")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **State & Season Yield**

# %%
state_season_yield = df.pivot_table(
    values="Yield_Tonnes_Ha",
    index="State",
    columns="Season",
    aggfunc="mean"
)
state_season_yield
# Out:
# Season            Kharif      Rabi      Zaid
# State
# Andhra Pradesh  5.693431  3.488069  4.480238
# Gujarat         6.338416  5.517245  4.101970
# Karnataka       6.523689  4.609655  6.623243
# Madhya Pradesh  6.004133  3.800000  5.539194
# Maharashtra     5.447014  5.501927  2.285352
# Punjab          4.100633  8.609355  5.909610
# Tamil Nadu      5.520534  4.555539  4.097746
# Telangana       5.568798  4.831649  4.278333

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(
    state_season_yield,
    annot=True,
    fmt=".2f"
)
plt.title("Average Yield by State and Season")
plt.xlabel("Season")
plt.ylabel("State")
plt.show()

# %% [markdown]
# # **Crop-wise Seasonal Analysis**

# %%
crop_season_yield = df.pivot_table(
    values="Yield_Tonnes_Ha",
    index="Crop",
    columns="Season",
    aggfunc="mean"
)
crop_season_yield
# Out:
# Season        Kharif       Rabi       Zaid
# Crop
# Chilli      1.731413   1.461615   1.177742
# Cotton      1.372804   1.192915   0.951648
# Groundnut   1.483646   1.221445   1.037778
# Maize       2.966410   2.614913   2.297590
# Pulses      1.036063   0.871887   0.652131
# Rice        2.707621   2.333680   1.900490
# Sugarcane  53.459120  43.940394  38.423922
# Wheat       2.255430   2.058814   1.748588

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(
    crop_season_yield,
    annot=True,
    fmt=".2f"
)
plt.title("Crop Yield Across Different Seasons")
plt.xlabel("Season")
plt.ylabel("Crop")
plt.show()

# %% [markdown]
# # **Disease/Pest Risk Analysis**

# %%
risk_by_season = df.groupby(
    "Season"
)["Disease_Pest_Risk_pct"].mean()
risk_by_season
# Out:
# Season
# Kharif    54.467903
# Rabi      40.482114
# Zaid      38.216667
# Name: Disease_Pest_Risk_pct, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(
    data=df,
    x="Season",
    y="Disease_Pest_Risk_pct"
)
plt.title("Disease and Pest Risk Across Seasons")
plt.xlabel("Season")
plt.ylabel("Risk (%)")
plt.show()

# %% [markdown]
# # **Pest Risk vs Yield**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Disease_Pest_Risk_pct",
    y="Yield_Tonnes_Ha",
    hue="Season"
)
plt.title("Disease/Pest Risk vs Crop Yield")
plt.xlabel("Disease/Pest Risk (%)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %%
df["Disease_Pest_Risk_pct"].corr(
    df["Yield_Tonnes_Ha"]
)
# Out:
# np.float64(0.013489880611057494)

# %% [markdown]
# # **Correlation Matrix**

# %%
numeric_df = df.select_dtypes(
    include=np.number
)
correlation_matrix = numeric_df.corr()

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f"
)
plt.title("Correlation Matrix of Agricultural Variables")
plt.show()

# %%
important_columns = [
    "Rainfall_mm",
    "Avg_Temperature_C",
    "Humidity_pct",
    "Sunlight_Hours_Day",
    "Soil_pH",
    "Soil_Moisture_pct",
    "Fertilizer_kg_ha",
    "Pesticide_Litre_ha",
    "Seed_Quality_Score",
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR",
    "Water_Used_m3",
    "Water_Efficiency_t_per_1000m3",
    "Disease_Pest_Risk_pct"
]
plt.figure(figsize=(16, 12))
sns.heatmap(
    df[important_columns].corr(),
    annot=True,
    fmt=".2f"
)
plt.title("Correlation Matrix of Key Agricultural Variables")
plt.show()

# %% [markdown]
# # **Statistical Analysis: ANOVA**

# %% [markdown]
# Season Groups

# %%
season_groups = [
    group["Yield_Tonnes_Ha"].dropna()
    for name, group in df.groupby("Season")
]

# %% [markdown]
# ANOVA

# %%
f_statistic, p_value = stats.f_oneway(
    *season_groups
)
print("F-statistic:", f_statistic)
print("P-value:", p_value)
# Out:
# F-statistic: 1.4579589466621523
# P-value: 0.23283549440109827

# %% [markdown]
# Decision

# %%
alpha = 0.05
if p_value < alpha:
    print("The difference in yield across seasons is statistically significant.")
else:
    print("The difference in yield across seasons is not statistically significant.")
# Out:
# The difference in yield across seasons is not statistically significant.

# %% [markdown]
# # **Overall Seasonal Performance Table**

# %%
seasonal_performance = df.groupby("Season").agg(
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Average_Production=("Production_Tonnes", "mean"),
    Average_Revenue=("Revenue_INR", "mean"),
    Average_Cost=("Total_Cost_INR", "mean"),
    Average_Profit=("Profit_INR", "mean"),
    Average_Water_Used=("Water_Used_m3", "mean"),
    Average_Water_Efficiency=("Water_Efficiency_t_per_1000m3", "mean"),
    Average_Pest_Risk=("Disease_Pest_Risk_pct", "mean")
)
seasonal_performance
# Out:
#         Average_Yield  Average_Production  Average_Revenue   Average_Cost  \
# Season
# Kharif       5.643973           46.311192    710719.055649  531804.408094
# Rabi         5.080498           41.486712    601526.048556  513836.578365
# Zaid         4.665942           38.886111    519171.904040  543976.728956
#
#         Average_Profit  Average_Water_Used  Average_Water_Efficiency  \
# Season
# Kharif   178914.647555         6102.201237                  5.891834
# Rabi      87689.470191         5846.987093                  5.186122
# Zaid     -24804.824916         6419.893939                  4.413239
#
#         Average_Pest_Risk
# Season
# Kharif          54.467903
# Rabi            40.482114
# Zaid            38.216667

# %% [markdown]
# # **Find Best Season**

# %% [markdown]
# According to yield

# %%
best_yield_season = seasonal_performance[
    "Average_Yield"
].idxmax()
print("Best season based on average yield:", best_yield_season)
# Out:
# Best season based on average yield: Kharif

# %% [markdown]
# According to profit

# %%
best_profit_season = seasonal_performance[
    "Average_Profit"
].idxmax()
print("Best season based on average profit:", best_profit_season)
# Out:
# Best season based on average profit: Kharif

# %% [markdown]
# According to water efficiency

# %%
best_water_season = seasonal_performance[
    "Average_Water_Efficiency"
].idxmax()
print(
    "Best season based on water efficiency:",
    best_water_season
)
# Out:
# Best season based on water efficiency: Kharif

# %% [markdown]
# # **Find Highest Risk Season**

# %%
highest_risk_season = seasonal_performance[
    "Average_Pest_Risk"
].idxmax()
print(
    "Season with highest disease/pest risk:",
    highest_risk_season
)
# Out:
# Season with highest disease/pest risk: Kharif

# %% [markdown]
# Highest water consumption

# %%
highest_water_season = seasonal_performance[
    "Average_Water_Used"
].idxmax()
print(
    "Season with highest water usage:",
    highest_water_season
)
# Out:
# Season with highest water usage: Zaid

# %% [markdown]
# # **Final Findings**

# %%
print(
    "Highest average yield:",
    seasonal_performance["Average_Yield"].idxmax()
)
print(
    "Highest average profit:",
    seasonal_performance["Average_Profit"].idxmax()
)
print(
    "Highest water usage:",
    seasonal_performance["Average_Water_Used"].idxmax()
)
print(
    "Highest water efficiency:",
    seasonal_performance["Average_Water_Efficiency"].idxmax()
)
print(
    "Highest disease/pest risk:",
    seasonal_performance["Average_Pest_Risk"].idxmax()
)
# Out:
# Highest average yield: Kharif
# Highest average profit: Kharif
# Highest water usage: Zaid
# Highest water efficiency: Kharif
# Highest disease/pest risk: Kharif

# %% [markdown]
# # **Results**

# %%
df.to_csv(
    "cleaned_agriculture_dataset.csv",
    index=False
)

# %%
seasonal_performance.to_csv(
    "seasonal_performance_summary.csv"
)

# %%
state_season_yield.to_csv(
    "state_season_yield.csv"
)

# %%
crop_season_yield.to_csv(
    "crop_season_yield.csv"
)

# %% [markdown]
# # **Conclusion:-**
# The Seasonal Agriculture Performance Analysis helped identify how agricultural performance varies across different seasons and farming conditions. The analysis revealed useful patterns in environmental factors, resource usage, crop performance, and economic outcomes. Overall, the project shows that data analytics can help understand seasonal variations and support better agricultural planning and resource management.
